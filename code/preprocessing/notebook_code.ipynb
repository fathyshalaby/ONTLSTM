# %%
import pickle
import pandas as pd
import numpy as np
# !pip install biopython
# Out:
# ...
#      |████████████████████████████████| 2.4MB 1.0MB/s eta 0:00:01
# ...

# %%
with open('uni2go_.pkl', 'rb') as f:
    fulldata = pickle.load(f)
fulldata
# Out:
# OrderedDict([('Q9Y263',
#               [5634,
#                16005,
#                5515,
#                1900045,
#                45202,
#                43161,
#                43162,
#                6693,
#                6954,
#                32430,
#                70062,
#                71222,
#                1903423,
#                2001224,
#                30054,
#                5737,
#                16236,
#                10992,
#                6644,
#                1903861,
#                5623,
#                43130,
#                7165]),
#              ('Q96RE7', [5634, 30054, 5737, 45892, 5654, 8284, 43231]),
#              ('Q15319',
#               [5634,
#                5737,
#                5654,
#                790,
#                48675,
#                7601,
#                7605,
#                21562,
#                31290,
#                50885,
#                51402,
#                30154,
#                1228,
# ...
